# %% [markdown]
# # Information Extraction and NER (Named Entity Recognition)

# %%
import spacy

spacy.__version__
# Out:
# '3.7.5'

# %% [markdown]
# > [Spacy models available](https://spacy.io/models/en)

# %%
import en_core_web_sm

nlp = en_core_web_sm.load() # Spacy model, creates a pipeline with a number components

# Components: tok2vec, tagger, parser, senter, ner, attribute_ruler, lemmatizer.

# %%
doc = nlp(
    'Nintendo Co Ltd 7974.T said on Thursday third-quarter operating profit rose 6%,driven by Switch console sales in the year-end shopping season, but the earnings fell below market expectations.Profit for the October-December quarter was 168.7 billion yen ($1.54 billion) versus 158.6 billion yen a year earlier.That compared with an average forecast of 175 billion yen from 10 analyst estimates compiled by Refinitiv.'
)

# %% [markdown]
# ## NER

# %%
ner = [(X.text, X.label_) for X in doc.ents] # traversing all the entities

ner
# Out:
# [('Nintendo Co Ltd', 'ORG'),
#  ('Thursday third-quarter', 'DATE'),
#  ('6%,driven', 'CARDINAL'),
#  ('Switch', 'ORG'),
#  ('the year-end shopping season', 'DATE'),
#  ('October-December quarter', 'DATE'),
#  ('168.7 billion yen', 'MONEY'),
#  ('$1.54 billion', 'MONEY'),
#  ('158.6 billion yen', 'MONEY'),
#  ('a year earlier', 'DATE'),
#  ('175 billion yen', 'MONEY'),
#  ('10', 'CARDINAL'),
#  ('Refinitiv', 'ORG')]

# %% [markdown]
# > Extracting IOB of an Entity
#
# > The IOB format (Inside-Outside-Beginning) is a standard format used for representing named entities in a sentence.
#
#     B-: Beginning of an entity (e.g., B-PER for "Beginning of a Person entity").
#
#     I-: Inside of an entity (e.g., I-PER for "Inside of a Person entity").
#
#     O: Outside of an entity (not part of any named entity).

# %%
tag = [(X, X.ent_iob_, X.ent_type_) for X in doc]

tag
# Out:
# [(Nintendo, 'B', 'ORG'),
#  (Co, 'I', 'ORG'),
#  (Ltd, 'I', 'ORG'),
#  (7974.T, 'O', ''),
#  (said, 'O', ''),
#  (on, 'O', ''),
#  (Thursday, 'B', 'DATE'),
#  (third, 'I', 'DATE'),
#  (-, 'I', 'DATE'),
#  (quarter, 'I', 'DATE'),
#  (operating, 'O', ''),
#  (profit, 'O', ''),
#  (rose, 'O', ''),
#  (6%,driven, 'B', 'CARDINAL'),
#  (by, 'O', ''),
#  (Switch, 'B', 'ORG'),
#  (console, 'O', ''),
#  (sales, 'O', ''),
#  (in, 'O', ''),
#  (the, 'B', 'DATE'),
#  (year, 'I', 'DATE'),
#  (-, 'I', 'DATE'),
#  (end, 'I', 'DATE'),
#  (shopping, 'I', 'DATE'),
#  (season, 'I', 'DATE'),
#  (,, 'O', ''),
#  (but, 'O', ''),
#  (the, 'O', ''),
#  (earnings, 'O', ''),
#  (fell, 'O', ''),
#  (below, 'O', ''),
#  (market, 'O', ''),
#  (expectations, 'O', ''),
#  (., 'O', ''),
#  (Profit, 'O', ''),
#  (for, 'O', ''),
#  (the, 'O', ''),
#  (October, 'B', 'DATE'),
#  (-, 'I', 'DATE'),
#  (December, 'I', 'DATE'),
#  (quarter, 'I', 'DATE'),
#  (was, 'O', ''),
#  (168.7, 'B', 'MONEY'),
#  (billion, 'I', 'MONEY'),
#  (yen, 'I', 'MONEY'),
#  ((, 'O', ''),
#  ($, 'B', 'MONEY'),
#  (1.54, 'I', 'MONEY'),
#  (billion, 'I', 'MONEY'),
#  (), 'O', ''),
#  (versus, 'O', ''),
#  (158.6, 'B', 'MONEY'),
#  (billion, 'I', 'MONEY'),
#  (yen, 'I', 'MONEY'),
#  (a, 'B', 'DATE'),
#  (year, 'I', 'DATE'),
#  (earlier, 'I', 'DATE'),
#  (., 'O', ''),
#  (That, 'O', ''),
#  (compared, 'O', ''),
#  (with, 'O', ''),
#  (an, 'O', ''),
#  (average, 'O', ''),
#  (forecast, 'O', ''),
#  (of, 'O', ''),
#  (175, 'B', 'MONEY'),
#  (billion, 'I', 'MONEY'),
#  (yen, 'I', 'MONEY'),
#  (from, 'O', ''),
#  (10, 'B', 'CARDINAL'),
#  (analyst, 'O', ''),
#  (estimates, 'O', ''),
#  (compiled, 'O', ''),
#  (by, 'O', ''),
#  (Refinitiv, 'B', 'ORG'),
#  (., 'O', '')]

# %%
# Some more examples

doc1 = nlp('Labour is a centre-left political party in the United Kingdom that has been described as an alliance of social democrats, democratic socialists and trade unionists. In all general elections since 1922, Labour has been either the governing party or the Official Opposition.')

ner = [(X.text, X.label_) for X in doc1.ents]

ner
# Out:
# [('Labour', 'ORG'),
#  ('the United Kingdom', 'GPE'),
#  ('democrats', 'NORP'),
#  ('democratic', 'NORP'),
#  ('socialists', 'NORP'),
#  ('1922', 'DATE'),
#  ('Labour', 'ORG'),
#  ('the Official Opposition', 'ORG')]

# %% [markdown]
# ### Fetching text from Internet (say a news article)

# %%
import requests

def url_to_string(url):
    try:
        # Send a GET request to the URL
        response = requests.get(url)

        # Raise an error if the request was unsuccessful
        response.raise_for_status()

        # Return the raw HTML content as a string
        return response.text

    except requests.exceptions.RequestException as e:
        # Handle any exceptions (like connection errors)
        print(f"Error fetching the URL: {e}")
        return None

# %%
text = url_to_string('https://www.bbc.com/news/articles/cx24gze60yzo')

text
# Out:
# '<!DOCTYPE html><html lang="en-GB"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width"/><title>Here&#x27;s who is in Trump cabinet and other top staff positions</title><meta property="og:title" content="Here&#x27;s who is in Trump cabinet and other top staff positions"/><meta name="twitter:title" content="Here&#x27;s who is in Trump cabinet and other top staff positions"/><meta name="description" content="Trump&#x27;s inner circle includes the world&#x27;s richest man, a former NFL player, and a Wall Street financer."/><meta property="og:description" content="Trump&#x27;s inner circle includes the world&#x27;s richest man, a former NFL player, and a Wall Street financer."/><meta name="twitter:description" content="Trump&#x27;s inner circle includes the world&#x27;s richest man, a former NFL player, and a Wall Street financer."/><meta property="og:image" content="https://ichef.bbci.co.uk/news/1024/branded_news/3d97/live/0dad93f0-ad90-11ef-8ab9-9192db313061.jpg"/><meta name="twitter:image:src" content="https://ichef.bbci.co.uk/news/1024/branded_news/3d97/live/0dad93f0-ad90-11ef-8ab9-9192db313061.jpg"/><meta name="twitter:card" content="summary_large_image"/><meta property="og:image:alt" content="BBC composite image of Elon Musk, Tulsi Gabbard and Robert F Kennedy Jr"/><meta name="twitter:image:alt" content="BBC composite image of Elon Musk, Tulsi Gabbard and Robert F Kennedy Jr"/><meta name="msapplication-TileColor" content="#da532c"/><meta name="theme-color" content="#ffffff"/><meta name="robots" content="NOODP, NOYDIR"/><meta name="apple-itunes-app" content="app-id=364147881, app-argument=https://www.bbc.com/news/articles/cx24gze60yzo"/><link rel="amphtml" href="https://www.bbc.com/news/articles/cx24gze60yzo.amp"/><link rel="apple-touch-icon" sizes="180x180" href="/bbcx/apple-touch-icon.png"/><link rel="icon" type="image/png" sizes="32x32" href="/bbcx/favicon-32x32.png"/><link rel="icon" type="image/png" sizes="16x16" href="/bbcx/favicon-16x16.png"/><link rel="alternate icon" href="/bbcx/favicon.ico"/><link rel="manifest" href="/bbcx/site.webmanifest"/><link rel="mask-icon" href="/bbcx/safari-pinned-tab.svg" color="#000000"/><link rel="canonical" href="https://www.bbc.com/news/articles/cx24gze60yzo"/><link data-testid="en-hreflang-tag" rel="alternate" hrefLang="en" href="https://www.bbc.com/news/articles/cx24gze60yzo"/><link data-testid="en-gb-hreflang-tag" rel="alternate" hrefLang="en-gb" href="https://www.bbc.co.uk/news/articles/cx24gze60yzo"/><meta name="version" content="2.16.1+2"/><script type="application/ld+json">{"@context":"http://schema.org","@type":"ReportageNewsArticle","url":"https://www.bbc.com/news/articles/cx24gze60yzo","publisher":{"@type":"NewsMediaOrganization","name":"BBC News","publishingPrinciples":"http://www.bbc.co.uk/news/help-41670342","logo":{"@type":"ImageObject","url":"https://static.files.bbci.co.uk/ws/simorgh-assets/public/news/images/metadata/poster-1024x576.png"}},"datePublished":"2024-11-08T03:15:53.095Z","dateModified":"2025-02-25T22:50:01.477Z","description":"Trump\'s inner circle includes the world\'s richest man, a former NFL player, and a Wall Street financer.","headline":"Here\'s who is in Trump cabinet and other top staff positions","image":{"@type":"ImageObject","width":1024,"height":576,"url":"https://ichef.bbci.co.uk/news/1024/branded_news/3d97/live/0dad93f0-ad90-11ef-8ab9-9192db313061.jpg"},"thumbnailUrl":"https://ichef.bbci.co.uk/news/1024/branded_news/3d97/live/0dad93f0-ad90-11ef-8ab9-9192db313061.jpg","mainEntityOfPage":"https://www.bbc.com/news/articles/cx24gze60yzo","author":{"@type":"NewsMediaOrganization","name":"BBC News","noBylinesPolicy":"http://www.bbc.co.uk/news/help-41670342#authorexpertise","logo":{"@type":"ImageObject","url":"https://static.files.bbci.co.uk/ws/simorgh-assets/public/news/images/metadata/poster-1024x576.png"}}}</script><meta property="al:ios:url" content="bbcx://news/articles/cx24gze60yzo"/><meta property="al:ios:app_store_id ...

# %%
from bs4 import BeautifulSoup
import requests
import re

def html_text(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html5lib')

    for script in soup(["script", "style", 'aside']):
        script.extract()

    return " ".join(re.split(r'[\n\t]+', soup.get_text()))

html_text('https://www.bbc.com/news/articles/cx24gze60yzo')
# Out:
# %% [markdown]
# ## Using spacy pipeline for processing

# %%
article = nlp(text)

# %%
len(article.ents)
# Out:
# 240

# %%
labels = [x.label_ for x in article.ents]

set(labels)
# Out:
# {'CARDINAL',
#  'DATE',
#  'GPE',
#  'LOC',
#  'MONEY',
#  'NORP',
#  'ORDINAL',
#  'ORG',
#  'PERSON',
#  'TIME'}

# %% [markdown]
# Let's count the labels in the article

# %%
from collections import Counter

Counter(labels)
# Out:
# Counter({'ORG': 106,
#          'GPE': 31,
#          'PERSON': 56,
#          'DATE': 22,
#          'TIME': 2,
#          'ORDINAL': 5,
#          'NORP': 7,
#          'LOC': 3,
#          'MONEY': 5,
#          'CARDINAL': 3})

# %% [markdown]
# Most common words

# %%
items = [x.text for x in article.ents]

Counter(items).most_common(3)
# Out:
# [('Trump', 27), ('US', 9), ('first', 5)]

# %%
sentences = [x for x in article.sents]

print(sentences[0], sentences[20], sep="\n\n")
# Out:
# Here's who is in Trump cabinet and other top staff positionsSkip to contentBritish Broadcasting CorporationWatch LiveHomeNewsSportBusinessInnovationCultureArtsTravelEarthAudioVideoLiveHomeNewsIsrael-Gaza WarWar in UkraineUS & CanadaUKUK PoliticsEnglandN. IrelandN. Ireland PoliticsScotlandScotland PoliticsWalesWales PoliticsAfricaAsiaChinaIndiaAustraliaEuropeLatin AmericaMiddle EastIn PicturesBBC InDepthBBC VerifySportBusinessExecutive
#
# "Pam was a prosecutor for nearly 20 years, tough on violent criminals, and made Florida's streets safe," he wrote.

# %% [markdown]
# Let's visualize

# %%
from spacy import displacy # Visualize spaCy’s guess at the syntactic structure of a sentence. Arrows point from children to heads, and are labelled by their relation type.

displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nintendo Co Ltd
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  7974.T said on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Thursday third-quarter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  operating profit rose
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6%,driven
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Switch
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  console sales in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the year-end shopping season
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , but the earnings fell below market expectations.Profit for the
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     October-December quarter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  was
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     168.7 billion yen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $1.54 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
# ) versus
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     158.6 billion yen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a year earlier
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .That compared with an average forecast of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     175 billion yen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  from
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  analyst estimates compiled by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Refinitiv
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .</div></span>

# %%
displacy.render(nlp(str(sentences[20])), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">&quot;Pam was a prosecutor for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nearly 20 years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , tough on violent criminals, and made
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Florida
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# 's streets safe,&quot; he wrote.</div></span>

# %%
displacy.render(doc1, jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Labour
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is a centre-left political party in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United Kingdom
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  that has been described as an alliance of social
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     democrats
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# ,
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     democratic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     socialists
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  and trade unionists. In all general elections since
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1922
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Labour
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has been either the governing party or
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Official Opposition
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .</div></span>

# %%
displacy.render(doc1, style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="9fc138ab0d09459a9ed73a7dd894c526-0" class="displacy" width="5210" height="377.0" direction="ltr" style="max-width: none; height: 377.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Labour</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">centre-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">left</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">political</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">party</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">United</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">Kingdom</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">has</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">been</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">described</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">alliance</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">social</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">democrats,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">democratic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">socialists</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="2810">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2810">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="2930">trade</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2930">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">unionists.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="3170">In</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3170">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="3290">all</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3290">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="3410">general</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3410">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="3530">elections</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3530">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">since</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="cu
